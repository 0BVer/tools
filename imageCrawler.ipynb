# %%
target = [#'affenpinscher',
#'afghan_hound',
#'african_hunting_dog',
#'airedale',
#'american_staffordshire_terrier',
#'appenzeller',
#'australian_terrier',
#'basenji',
#'basset',
#'beagle',
#'bedlington_terrier',
#'bernese_mountain_dog',
#'black-and-tan_coonhound',
#'blenheim_spaniel',
#'bloodhound',
#'bluetick',
#'border_collie',
#'border_terrier',
#'borzoi',
#'boston_bull',
#'bouvier_des_flandres',
#'boxer',
#'brabancon_griffon',
#'briard',
#'brittany_spaniel',
#'bull_mastiff',
#'cairn',
#'cardigan',
#'chesapeake_bay_retriever',
#'chihuahua',
#'chow',
#'clumber',
#'cocker_spaniel',
#'collie',
#'curly-coated_retriever',
#'dandie_dinmont',
#'dhole',
#'dingo',
#'doberman',
#'english_foxhound',
#'english_setter',
#'english_springer',
#'entlebucher',
#'eskimo_dog',
#'flat-coated_retriever',
#'french_bulldog',
#'german_shepherd',
#'german_short-haired_pointer',
#'giant_schnauzer',
#'golden_retriever',
#'gordon_setter',
#'great_dane',
#'great_pyrenees',
#'greater_swiss_mountain_dog',
#'groenendael',
#'ibizan_hound',
#'irish_setter',
#'irish_terrier',
#'irish_water_spaniel',
#'irish_wolfhound',
#'italian_greyhound',
#'japanese_spaniel',
#'keeshond',
#'kelpie',
#'kerry_blue_terrier',
#'komondor',
'kuvasz',
#'labrador_retriever',
#'lakeland_terrier',
#'leonberg',
#'lhasa',
#'malamute',
#'malinois',
#'maltese_dog',
#'mexican_hairless',
#'miniature_pinscher',
#'miniature_poodle',
#'miniature_schnauzer',
#'newfoundland',
#'norfolk_terrier',
#'norwegian_elkhound',
#'norwich_terrier',
#'old_english_sheepdog',
#'otterhound',
#'papillon',
#'pekinese',
#'pembroke', #에러 데이터가 너무 많음
#'pomeranian',
#'pug',
#'redbone',
#'rhodesian_ridgeback',
#'rottweiler',
#'saint_bernard',
#'saluki',
#'samoyed',
#'schipperke',
#'scotch_terrier',
#'scottish_deerhound',
#'sealyham_terrier',
#'shetland_sheepdog',
#'shih-tzu',
#'siberian_husky',
#'silky_terrier',
#'soft-coated_wheaten_terrier',
#'staffordshire_bullterrier',
#'standard_poodle',
#'standard_schnauzer',
#'sussex_spaniel',
#'tibetan_mastiff',
#'tibetan_terrier',
#'toy_poodle',
#'toy_terrier',
#'vizsla',
#'walker_hound',
#'weimaraner',
#'welsh_springer_spaniel',
#'west_highland_white_terrier',
#'whippet',
#'wire-haired_fox_terrier',
#'yorkshire_terrier'
]

# %%
#name = 'iu' #검색어
how_many = 200 #가져올 사진 수
path = 'C:\\Users\\BVer\\image_crawler\\' #해당 코드 파일 위치 

from selenium import webdriver
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
from urllib.parse import quote_plus
from selenium.webdriver.common.keys import Keys
import urllib.request
import time
import os
import shutil

import threading
import time
from apscheduler.schedulers.background import BackgroundScheduler
 

def start_findI():
    t = threading.Thread(target=findI)
    t.start()
    return t

def findI():
    findI = threading.currentThread()
    image.click()
    time.sleep(1.7)
    imgUrl = driver.find_element_by_xpath('/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img').get_attribute("src")
    urllib.request.urlretrieve(imgUrl, name + str(count) + ".jpg")
    #print(name + str(count) + ".jpg --- find")

sched = BackgroundScheduler()
sched.start()
for name in target:
    driver = webdriver.Chrome(path + 'chromedriver.exe')
    driver.get("https://www.google.co.kr/imghp?hl=ko&ogbl")
    elem = driver.find_element_by_name("q")
    elem.send_keys(name)
    elem.send_keys(Keys.RETURN)
 
    SCROLL_PAUSE_TIME = 1
 
    last_height = driver.execute_script("return document.body.scrollHeight")
 
    while True: #페이지 로딩
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(SCROLL_PAUSE_TIME)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            try:
                driver.find_element_by_css_selector(".mye4qd").click()
            except:
                break
        last_height = new_height
 
    images = driver.find_elements_by_css_selector(".rg_i.Q4LuWd")
    print(name + ' crawling ready')
    
    try: #name 폴더 만들기
        os.makedirs(path + '\\' + name)
    except:
        pass
    

    count = 1
    trycount = 0
    for image in images: #로딩된 페이지에서 크롤링
        if(sched.running): #스레드가 작동중이지 않으면 멈춤
            trycount += 1
            try:
                t = start_findI()
            except:
                if(trycount > how_many*3):
                    print(name + ' crawling ERROR')
                    break
                else:
                    pass
            finally:
                time.sleep(3)
                try:     
                    t.do_run = False             
                except:
                    pass
                finally:
                    try:
                        if(os.path.isfile('{0}{1}.jpg'.format(path, name + str(count)))): #파일 저장 확인 후 이동 시키고 카운트업
                            from_ = '{0}{1}.jpg'.format(path, name + str(count))
                            to_ = '{0}{1}\{2}.jpg'.format(path, name, name + '_0' + str(count))
                            shutil.move(from_, to_)
                            count += 1
                    except:
                        pass
                    finally:
                        if(count > how_many):
                            break     
        else:
            break
    try:
        driver.close()
    except:
        pass
    finally:
        print(name + '------------------ complete')
        
print('CRAWLING COMPLETE')
# Out:
# kuvasz crawling ready
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="210" height="210" data-index="0" alt="Hungarian Kuvasz Breed Information, Characteristics &amp; Heath Problems |  DogZone.com" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTr2QtyObnqk_74bHPr4sHi6mVoGLPN1DoJTA&amp;usqp=CAU"> is not clickable at point (125, 636). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 502px;">...</div>
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 404: Not Found
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="223" height="207" data-index="0" alt="Kuvasz Caring - Vtwctr" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS2L0by0CnVpIqgLJA55BI1KROZX6FPiQ31fA&amp;usqp=CAU"> is not clickable at point (149, 634). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 502px;">...</div>
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-67:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="167" height="251" data-index="0" alt="5 Things You Didn't Know About the Kuvasz – American Kennel Club" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTr2Kx5nCgMA9hYLyevMgDy0wMWOmF66R4Bog&amp;usqp=CAU"> is not clickable at point (400, 610). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 502px;">...</div>
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-81:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-85:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-89:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-96:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-98:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-100:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-101:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-104:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-105:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-106:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 29, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[2]/c-wiz/div[3]/div[2]/div[3]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div/div[2]/a/img"}
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-120:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-125:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-127:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-132:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="162" height="250" data-index="104" alt="AKC Kuvasz Study Guide by Kuvasz Fanciers - issuu" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS62iLeY7RrpigzOm6EEn4Mtsy5asrs3zTtbQ&amp;usqp=CAU"> is not clickable at point (107, 636). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 502px;">...</div>
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-137:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element is not clickable at point (261, 657)
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-146:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-151:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-162:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-163:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-164:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-168:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-174:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-176:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-183:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-192:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# ...
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element is not clickable at point (261, 657)
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-282:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-283:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-286:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-288:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-294:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementClickInterceptedException: Message: element click intercepted: Element <img data-ils="4" jsaction="rcuQ6b:trigger.M8vzZb;" class="rg_i Q4LuWd" jsname="Q4LuWd" width="210" height="210" data-index="208" alt="7AL-Kuvasz Silhouette 48” arc umbrella that closes away from" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRR3Cny0NQECMIXfQ0mGlk9GEFng7gQ_iPoFQ&amp;usqp=CAU"> is not clickable at point (125, 638). Other element would receive the click: <div jsname="r5xl4" class="islrc" style="width: 502px;">...</div>
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-298:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 27, in findI
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 80, in click
#     self._execute(Command.CLICK_ELEMENT)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py", line 633, in _execute
#     return self._parent.execute(command, params)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\BVer\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.ElementNotInteractableException: Message: element not interactable: element has zero size
#   (Session info: chrome=91.0.4472.77)
#
# Exception in thread Thread-304:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-309:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-316:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-317:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-318:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# Exception in thread Thread-321:
# Traceback (most recent call last):
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "C:\Users\BVer\anaconda3\lib\threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-2-49166e83af09>", line 30, in findI
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 247, in urlretrieve
#     with contextlib.closing(urlopen(url, data)) as fp:
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 531, in open
#     response = meth(req, response)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 640, in http_response
#     response = self.parent.error(
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 569, in error
#     return self._call_chain(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 502, in _call_chain
#     result = func(*args)
#   File "C:\Users\BVer\anaconda3\lib\urllib\request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 403: Forbidden
# kuvasz------------------ complete
# CRAWLING COMPLETE
